# %% [markdown]
# # LOCAL SEARCH - ANÁLISE DE RESULTADOS
#
#  - ITA | PG-CTE-S | TE-282 - Meta-heurísticas
#  - Professor Dr. Angelo Passaro
#  - Aluno: Rafael Caneiro de Oliveira
#  - Versao: 0.1
#  - Data: 26/10/2021

# %% [markdown]
# ## Bibliotecas | Parâmetros | Funções

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import glob

PATH = Path.cwd().parent
RAW_PATH = Path(PATH, "./data/raw/") 
LOG_PATH = Path(PATH, "./data/log/")
print(LOG_PATH)
# Out:
# /Users/rco/OneDrive/ITA/Mestrado/2021_TE-282 - Meta heurísticas/Lab/data/log

# %%
def read_port_files(n_port):
    filepath = Path(RAW_PATH, 'port' + str(n_port) + '.txt')
    with open(filepath) as fp:
        # quantidade de ativos no portfolio
        n_assets = int(fp.readline())
        # armazena as estatisticas do ativo
        r_mean = []
        r_std = []
        for n in range(n_assets):
            line = fp.readline()
            r_mean.append(float(line.strip().split()[0]))
            r_std.append(float(line.strip().split()[1]))

        # obtem o restante da matriz de covariancia
        cnt = 32
        i = []
        j = []
        cov = []
        line = fp.readline()
        while line:
            i.append(int(line.strip().split(' ')[0]))
            j.append(int(line.strip().split(' ')[1]))
            cov.append(float(line.strip().split(' ')[2]))
            line = fp.readline()
    fp.close()
    # retorna dataframe com estatisticas dos ativos do portfolio
    df_stats = pd.DataFrame({'port':n_port,
                             'i':[i_+1 for i_ in range(n_assets)],
                             'r_mean':r_mean,
                             'r_std':r_std})
    print(df_stats.shape)

    # retorna dataframe com matriz de covariancia dos ativos do portfolio
    df_cov_mx = pd.DataFrame({'port':n_port,
                             'i':i,
                             'j':j,
                             'cov':cov})
    print(df_cov_mx.shape)
    return df_stats, df_cov_mx

# %% [markdown]
# ## Carrega Dados

# %%
df_stats_list = []
df_cov_mx_list =[]
for p in range(1,6,1):
    df_stats, df_cov_mx = read_port_files(p)
    df_stats_list.append(df_stats)
    df_cov_mx_list.append(df_cov_mx)
    
df_stats = pd.concat(df_stats_list)
df_cov_mx = pd.concat(df_cov_mx_list)
# Out:
# (31, 4)
# (496, 4)
# (85, 4)
# (3655, 4)
# (89, 4)
# (4005, 4)
# (98, 4)
# (4851, 4)
# (225, 4)
# (25425, 4)

# %%
all_dfs = []
best_dfs = []
LOGs = str(LOG_PATH) + '/*.csv'

for file in glob.glob(str(LOGs)):
    df = pd.read_csv(file)
    filename = file[file.find('/log/')+5:]
    df['filename'] = filename
    all_dfs.append(df)
    best_dfs.append(df.iloc[-1:])

all_data = pd.concat(all_dfs, ignore_index=True).reset_index(drop=True)
all_data.rename({'move_strategy':'move_str',
                 'selection_strategy':'selec_str'}, axis=1, inplace=True)

best_data = pd.concat(best_dfs, ignore_index=True).reset_index(drop=True)
best_data.rename({'move_strategy':'move_str',
                  'selection_strategy':'selec_str'}, axis=1, inplace=True)

# %%
# sns.set(style="ticks", context="notebook")
# plt.style.use("dark_background")

# %%
print(all_data.shape)
all_data.drop(['Z', 'X'],axis=1).head()
# Out:
# (136035, 23)
#    iter  move  improve       obj    return  n_assets   qN  qNv  iter_time  \
# 0     0   TID     True  0.192692  0.003517        12  100   22   0.013718
# 1     1   iDR     True  0.192626  0.003517        12  100  100   0.018346
# 2     2  idID     True  0.188034  0.003484        12  100   79   0.017517
# 3     3   TID     True  0.187891  0.003496        12  100   35   0.015258
# 4     4   TID     True  0.187885  0.003495        12  100   31   0.014109
#
#    max_iter  ...  alpha  exp_return  n_port  k_min  k_max  move_str  \
# 0      1000  ...   0.01       0.003       1     10     15    random
# 1      1000  ...   0.01       0.003       1     10     15    random
# 2      1000  ...   0.01       0.003       1     10     15    random
# 3      1000  ...   0.01       0.003       1     10     15    random
# 4      1000  ...   0.01       0.003       1     10     15    random
#
#   neighbour_strategy seed  selec_str                              filename
# 0               best    3     random  log_local_search_20211030_234541.csv
# 1               best    3     random  log_local_search_20211030_234541.csv
# 2               best    3     random  log_local_search_20211030_234541.csv
# 3               best    3     random  log_local_search_20211030_234541.csv
# 4               best    3     random  log_local_search_20211030_234541.csv
#
# [5 rows x 21 columns]

# %%
all_data.describe(include='all').T
# Out:
#                      count unique  \
# iter                136035    NaN
# move                136035      3
# improve             136035      2
# obj                 136035    NaN
# return              136035    NaN
# n_assets            136035    NaN
# X                   136035  50317
# Z                   136035   6086
# qN                  136035    NaN
# qNv                 136035    NaN
# iter_time           136035    NaN
# max_iter            136035    NaN
# neighbours          136035    NaN
# alpha               136035    NaN
# exp_return          136035    NaN
# n_port              136035    NaN
# k_min               136035    NaN
# k_max               136035    NaN
# move_str            136035      5
# neighbour_strategy  136035      1
# seed                136035    NaN
# selec_str           136035      3
# filename            136035    891
#
#                                                                   top    freq  \
# iter                                                              NaN     NaN
# move                                                              TID   72706
# improve                                                          True  101732
# obj                                                               NaN     NaN
# return                                                            NaN     NaN
# n_assets                                                          NaN     NaN
# X                   [0.13399012 0.14535705 0.06947518 0.00444784 0...    9129
# Z                               [ 1  2  4  5 14 15 16 17 18 20 27 28]   10936
# qN                                                                NaN     NaN
# qNv                                                               NaN     NaN
# iter_time                                                         NaN     NaN
# max_iter                                                          NaN     NaN
# neighbours                                                        NaN     NaN
# alpha                                                             NaN     NaN
# exp_return                                                        NaN     NaN
# n_port                                                            NaN     NaN
# k_min                                                             NaN     NaN
# k_max                                                             NaN     NaN
# move_str                                                       random   39224
# neighbour_strategy                                               best  136035
# seed                                                              NaN     NaN
# selec_str                                                      random   61926
# filename                         log_local_search_20211030_231520.csv    1000
#
#                           mean         std        min         25%        50%  \
# iter                   175.918     200.495          0          38         95
# move                       NaN         NaN        NaN         NaN        NaN
# improve                    NaN         NaN        NaN         NaN        NaN
# obj                   0.104327   0.0856816  0.0191204   0.0343873  0.0640932
# return              0.00350936  0.00146043      0.001  0.00262773  0.0033534
# n_assets               11.5857     1.80738         10          10         11
# X                          NaN         NaN        NaN         NaN        NaN
# Z                          NaN         NaN        NaN         NaN        NaN
# qN                         100           0        100         100        100
# qNv                    47.2021     25.5591          0          35         47
# iter_time            0.0188655  0.00822237   0.006663    0.014111   0.015968
# max_iter                  1000           0       1000        1000       1000
# neighbours                 100           0        100         100        100
# alpha                0.0272645    0.033748      0.001       0.003       0.01
# exp_return          0.00181717  0.00077595      0.001       0.001      0.002
# n_port                       1           0          1           1          1
# k_min                       10           0         10          10         10
# k_max                       15           0         15          15         15
# move_str                   NaN         NaN        NaN         NaN        NaN
# neighbour_strategy         NaN         NaN        NaN         NaN        NaN
# seed                    2.6122     1.43484          1           1          2
# selec_str                  NaN         NaN        NaN         NaN        NaN
# filename                   NaN         NaN        NaN         NaN        NaN
#
#                            75%        max
# iter                       235        999
# move                       NaN        NaN
# improve                    NaN        NaN
# obj                   0.173815   0.269245
# return              0.00409529  0.0102353
# n_assets                    12         15
# X                          NaN        NaN
# Z                          NaN        NaN
# qN                         100        100
# qNv                         63        100
# iter_time             0.018892   0.133444
# max_iter                  1000       1000
# neighbours                 100        100
# alpha                     0.03        0.1
# exp_return               0.002      0.003
# n_port                       1          1
# k_min                       10         10
# k_max                       15         15
# move_str                   NaN        NaN
# neighbour_strategy         NaN        NaN
# seed                         4          5
# selec_str                  NaN        NaN
# filename                   NaN        NaN

# %% [markdown]
# ## Portfólios

# %%
portfolios = {
    1:'Hang Seng - Hong Kong',
    2:'DAX - German Blue Chips',
    3:'FTSE - London',
    4:"S&P - Standard and Poor's 500 - US",
    5:'Nikkei - Tokyo'
}
df_stats['portfolio'] = df_stats.port.map(portfolios)
df_cov_mx['portfolio'] = df_cov_mx.port.map(portfolios)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4), gridspec_kw={'width_ratios': [1, 1.5]})
sns.countplot(data=df_stats, y='portfolio', ax=ax[0])
ax[0].title.set_text('Qtd de Ativos')
sns.boxplot(data=df_stats, y='portfolio', x='r_mean', ax=ax[1])
ax[1].title.set_text("Retorno Médio")
ax[1].get_yaxis().set_ticks([])
ax[1].set_ylabel('')
fig.tight_layout()

# %%
portfolio = 1
df_cov_pivot = df_cov_mx[df_cov_mx.port==portfolio].pivot(index='i', columns='j', values='cov')
sns.heatmap(df_cov_pivot.iloc[::-1], cmap="YlGnBu") 
plt.title(portfolios[portfolio])
ax=ax

# %%
portfolio = 2
df_cov_pivot = df_cov_mx[df_cov_mx.port==portfolio].pivot(index='i', columns='j', values='cov')
sns.heatmap(df_cov_pivot.iloc[::-1], cmap="YlGnBu") 
plt.title(portfolios[portfolio])
ax=ax

# %%
portfolio = 3
df_cov_pivot = df_cov_mx[df_cov_mx.port==portfolio].pivot(index='i', columns='j', values='cov')
sns.heatmap(df_cov_pivot.iloc[::-1], cmap="YlGnBu") 
plt.title(portfolios[portfolio])
ax=ax

# %%
portfolio = 4
df_cov_pivot = df_cov_mx[df_cov_mx.port==portfolio].pivot(index='i', columns='j', values='cov')
sns.heatmap(df_cov_pivot.iloc[::-1], cmap="YlGnBu") 
plt.title(portfolios[portfolio])
ax=ax

# %%
portfolio = 5
df_cov_pivot = df_cov_mx[df_cov_mx.port==portfolio].pivot(index='i', columns='j', values='cov')
sns.heatmap(df_cov_pivot.iloc[::-1], cmap="YlGnBu") 
plt.title(portfolios[portfolio])
ax=ax

# %% [markdown]
# ## Curvas de Aprendizado

# %% [markdown]
# ### Avaliação do Impacto da Seed

# %%
g = sns.FacetGrid(
    data=all_data, row='seed', col='move_strt', hue='alpha')
g.map(sns.lineplot, 'iter', 'obj')
g.add_legend()
g=g

# %%
all_data = all_data[all_data.seed.isin([1,2,3])]
all_data.shape
# Out:
# (57635, 23)

# %% [markdown]
# ### Avaliação do Tipo de Move

# %%
g = sns.FacetGrid(
    data=all_data, row='selec_strat', col='move_strt', hue='alpha')
g.map(sns.lineplot, 'iter', 'obj')
g.add_legend()
g=g

# %% [markdown]
# ### Avaliação do Impacto do Retorno Experado

# %%
g = sns.FacetGrid(
    data=all_data, row='exp_return', col='move_strt', hue='alpha')
g.map(sns.lineplot, 'iter', 'obj')
g.add_legend()
g=g

# %% [markdown]
# ## Análise Best

# %%
g = sns.FacetGrid(
    data=best_data, col='move_str', hue='alpha')
g.map(sns.scatterplot, 'return', 'obj')
